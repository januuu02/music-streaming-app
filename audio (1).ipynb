# %%
pip install --upgrade librosa numpy
# Out:
# ...
#   Obtaining dependency information for librosa from https://files.pythonhosted.org/packages/e2/a2/4f639c1168d7aada749a896afb4892a831e2041bebdcf636aebfe9e86556/librosa-0.10.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/3f/6b/5610004206cf7f8e7ad91c5a85a8c71b2f2f8051a0c0c4d5916b76d6cbb2/numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      ------------------------------- ------ 51.2/61.0 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 819.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/253.7 kB ? eta -:--:--
#    ------------ --------------------------- 81.9/253.7 kB 4.5 MB/s eta 0:00:01
#    ------------------- -------------------- 122.9/253.7 kB 1.4 MB/s eta 0:00:01
# ...

# %%
import librosa
import sounddevice as sd

# %%
audio, sr = librosa.load('trial.wav')
sd.play(audio, sr)
sd.wait()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(audio)
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.title('Audio Waveform')
plt.show()

# %%
audio, sr = librosa.load('trial2.wav')
sd.play(audio, sr)
sd.wait()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(audio)
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.title('Audio Waveform')
plt.show()

# %%
new_sr = 22050
resampled_audio = librosa.resample(audio, sr, new_sr)

# %%
duration = 10  # seconds
trimmed_audio = audio[:int(sr * duration)]

# %%
pip install --upgrade librosa
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
new_sr = int(sr * speed)
pitch_shifted_audio = librosa.resample(audio, sr, new_sr)

# %%
import numpy as np
silence_duration = 2
silence = np.zeros(int(sr * silence_duration))
audio_with_silence = np.concatenate((silence, audio))

# %%
pip install --upgrade librosa
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import soundfile as sf
sf.write('C:/Users/janan/Downloads/processed_audio.wav', audio, sr, subtype='PCM_24')
